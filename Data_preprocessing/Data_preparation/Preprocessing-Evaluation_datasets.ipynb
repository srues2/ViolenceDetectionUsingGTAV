# %% [markdown]
# ## Extract frames from one input video

# %%
# Function to extract frames from one video
import cv2
import os

def FrameCapture(path, dst_directory): 
    """
    Parameters:
        path: this is the path where the video is located
        dst_directory: the destination directory is the directory in which you want to save the frames
    Output:
        All frames of the video will be stored in the dst_directory
    """  
    
    folder = dst_directory 
    os.mkdir(folder)
    
    vidcap = cv2.VideoCapture(path)
    
    def getFrame(sec):
        vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
        hasFrames,image = vidcap.read()
        if hasFrames:
            cv2.imwrite(os.path.join(folder,"{:0=6d}.jpg".format(count)), image)     # save frame as JPG file
        return hasFrames
    sec = 0
    frameRate = (1/30) #it will capture image in each (1/30) second
    count=1
    success = getFrame(sec)
    
    while success:
        count = count + 1
        sec = sec + frameRate
        sec = round(sec, 2)
        success = getFrame(sec)
    
    print("{} images are extracted in {}.".format(count-1,folder))

# %% [markdown]
# ## Extract frames from videos in a given directory

# %%
# Function to extract frames from all videos of the given directory
import os

def VideosFrameExtractor(path, path_Videos): 
    """
    Parameters:
        path: the name of the directory to be created
        path_Videos: the name of the directory where the videos are located
    Output:
        Extract frames from all the videos of the given path where videos are stored
    """
    try:
        os.mkdir(path)
    except OSError:
        print ("Creation of the directory %s failed" % path)
    else:
        print ("Successfully created the directory %s " % path)
    
    
    for file in os.listdir(path_Videos):
        if not file.startswith("._") and file.endswith(".mpg"):
            FrameCapture(os.path.join(path_Videos + "/" + file), os.path.join( path + "/" + file.replace('.mp4','')))
            print("Frames extracted for video: ", file)

# %%
VideosFrameExtractor("/Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames", "/Volumes/LogisP/Videos/Movies_Fights/Movies/NoFights")  
#VideosFrameExtractor("/Volumes/LogisP/Videos/Movies_Fights/Movies/Violence_Frames", "/Volumes/LogisP/Videos/Movies_Fights/Movies/fights")
# Out:
# Successfully created the directory /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/17.mpg.
# Frames extracted for video:  17.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/16.mpg.
# Frames extracted for video:  16.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/28.mpg.
# Frames extracted for video:  28.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/14.mpg.
# Frames extracted for video:  14.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/100.mpg.
# Frames extracted for video:  100.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/15.mpg.
# Frames extracted for video:  15.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/29.mpg.
# Frames extracted for video:  29.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/11.mpg.
# Frames extracted for video:  11.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/39.mpg.
# Frames extracted for video:  39.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/20.mpg.
# Frames extracted for video:  20.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/38.mpg.
# Frames extracted for video:  38.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/10.mpg.
# Frames extracted for video:  10.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/13.mpg.
# Frames extracted for video:  13.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/48.mpg.
# Frames extracted for video:  48.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/74.mpg.
# Frames extracted for video:  74.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/60.mpg.
# Frames extracted for video:  60.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/61.mpg.
# Frames extracted for video:  61.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/75.mpg.
# Frames extracted for video:  75.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/49.mpg.
# Frames extracted for video:  49.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/63.mpg.
# Frames extracted for video:  63.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/77.mpg.
# Frames extracted for video:  77.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/88.mpg.
# Frames extracted for video:  88.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/89.mpg.
# Frames extracted for video:  89.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/76.mpg.
# Frames extracted for video:  76.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/62.mpg.
# Frames extracted for video:  62.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/41.mpg.
# Frames extracted for video:  41.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/66.mpg.
# Frames extracted for video:  66.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/72.mpg.
# Frames extracted for video:  72.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/8.mpg.
# Frames extracted for video:  8.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/99.mpg.
# Frames extracted for video:  99.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/98.mpg.
# Frames extracted for video:  98.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/9.mpg.
# Frames extracted for video:  9.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/73.mpg.
# Frames extracted for video:  73.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/65.mpg.
# Frames extracted for video:  65.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/59.mpg.
# Frames extracted for video:  59.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/58.mpg.
# Frames extracted for video:  58.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/64.mpg.
# Frames extracted for video:  64.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/70.mpg.
# Frames extracted for video:  70.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/69.mpg.
# Frames extracted for video:  69.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/7.mpg.
# Frames extracted for video:  7.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/55.mpg.
# Frames extracted for video:  55.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/96.mpg.
# Frames extracted for video:  96.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/82.mpg.
# Frames extracted for video:  82.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/83.mpg.
# Frames extracted for video:  83.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/97.mpg.
# Frames extracted for video:  97.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/40.mpg.
# Frames extracted for video:  40.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/6.mpg.
# Frames extracted for video:  6.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/54.mpg.
# Frames extracted for video:  54.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/68.mpg.
# Frames extracted for video:  68.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/56.mpg.
# Frames extracted for video:  56.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/81.mpg.
# Frames extracted for video:  81.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/95.mpg.
# Frames extracted for video:  95.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/94.mpg.
# Frames extracted for video:  94.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/80.mpg.
# Frames extracted for video:  80.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/57.mpg.
# Frames extracted for video:  57.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/5.mpg.
# Frames extracted for video:  5.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/42.mpg.
# Frames extracted for video:  42.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/47.mpg.
# Frames extracted for video:  47.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/1.mpg.
# Frames extracted for video:  1.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/53.mpg.
# Frames extracted for video:  53.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/84.mpg.
# Frames extracted for video:  84.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/43.mpg.
# Frames extracted for video:  43.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/90.mpg.
# Frames extracted for video:  90.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/91.mpg.
# Frames extracted for video:  91.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/85.mpg.
# Frames extracted for video:  85.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/52.mpg.
# Frames extracted for video:  52.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/46.mpg.
# Frames extracted for video:  46.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/50.mpg.
# Frames extracted for video:  50.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/2.mpg.
# Frames extracted for video:  2.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/44.mpg.
# Frames extracted for video:  44.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/78.mpg.
# Frames extracted for video:  78.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/93.mpg.
# Frames extracted for video:  93.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/87.mpg.
# Frames extracted for video:  87.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/86.mpg.
# Frames extracted for video:  86.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/92.mpg.
# Frames extracted for video:  92.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/79.mpg.
# Frames extracted for video:  79.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/45.mpg.
# Frames extracted for video:  45.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/51.mpg.
# Frames extracted for video:  51.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/3.mpg.
# Frames extracted for video:  3.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/71.mpg.
# Frames extracted for video:  71.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/36.mpg.
# Frames extracted for video:  36.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/22.mpg.
# Frames extracted for video:  22.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/67.mpg.
# Frames extracted for video:  67.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/23.mpg.
# Frames extracted for video:  23.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/37.mpg.
# Frames extracted for video:  37.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/21.mpg.
# Frames extracted for video:  21.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/35.mpg.
# Frames extracted for video:  35.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/12.mpg.
# Frames extracted for video:  12.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/34.mpg.
# Frames extracted for video:  34.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/24.mpg.
# Frames extracted for video:  24.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/30.mpg.
# Frames extracted for video:  30.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/18.mpg.
# Frames extracted for video:  18.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/19.mpg.
# Frames extracted for video:  19.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/31.mpg.
# Frames extracted for video:  31.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/25.mpg.
# Frames extracted for video:  25.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/26.mpg.
# Frames extracted for video:  26.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/33.mpg.
# Frames extracted for video:  33.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/27.mpg.
# Frames extracted for video:  27.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/32.mpg.
# Frames extracted for video:  32.mpg
# 54 images are extracted in /Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/4.mpg.
# Frames extracted for video:  4.mpg

# %% [markdown]
# ## Merge two text files

# %%
#Function to merge two textfiles
def MergeSequenceFiles(file_1, file_2, name_output_file):
    import os
    """
    Parameters:
        file_1: name of the first textfile
        file_2: name of the second textfile
        name_output_file: name of the generated output textfile 
    Output:
        Merged file
    """
    filenames = [file_1, file_2]
    with open(name_output_file, 'w') as outfile:
        for fname in filenames:
            with open(fname) as infile:
                for line in infile:
                    outfile.write(line)
    
    os.remove(file_1)
    os.remove(file_2)
    print("Merged two input files: " + file_1 + " and " + file_2)

# %% [markdown]
# ## Create sequences of frames on a directory

# %%
#Function to create seqeunces of frames of the given directory
 

def WriteInformationDirectoryFile(path_Videos, name_file_sequences, number_of_sequences, overlay_sequences, group_nr):
    """
    Parameters:
        path_Videos: path of directory which contains video frame directories
        name_file_sequences: name of the generated output file with sequences
        number_of_sequences: number of frames in one sequence
        overlay_sequences: number of frames overlay between sequences
        group_nr: number of sequence
    Output:
        The number of the last sequence & write a .txt file which contain sequences
    """
    
    DirectoryFile = open(name_file_sequences + ".txt", "w") 
    for file in os.listdir(path_Videos):
        total_number_frames = len(os.listdir(str(path_Videos) + str(file)) )
        start_frame = 1
        count_sequences = 1
        group_nr = group_nr + 1
        
        #Control directory contains violence frames, if violence -> violence = 1, else -> violence=0
        if("NoViolence_Frames" in path_Videos):
                violence = 0
        elif("Violence_Frames" in path_Videos):
                violence = 1
        
        while start_frame < total_number_frames+1:
            if( (start_frame+number_of_sequences) <= (total_number_frames+1) ):
                DirectoryFile.write(path_Videos + file + " " + str(start_frame) + " " + str(violence) + " " + str(group_nr)) 
                DirectoryFile.write("\n")
                
                #With 0 overlay -> start_frame = start_frame + number_of_sequences
                #with 8 overlay -> start_frame = start_frame + overlay_sequences
                start_frame = start_frame + overlay_sequences
                count_sequences = count_sequences + 1
                
            else:
                break

    DirectoryFile.close()    
    return group_nr

# %%
#write a file with the 16 frame sequences for the classes violence and non-violence
group_nr = WriteInformationDirectoryFile("/Volumes/LogisP/Videos/Movies_Fights/Movies/NoViolence_Frames/", "NoViolenceVideoInformation", 16, 8, 0)
WriteInformationDirectoryFile("/Volumes/LogisP/Videos/Movies_Fights/Movies/Violence_Frames/", "ViolenceVideoInformation", 16, 8, group_nr)
# Out:
# 200

# %%
MergeSequenceFiles("ViolenceVideoInformation.txt","NoViolenceVideoInformation.txt", "MoviesFights.txt")
# Out:
# Merged two input files: ViolenceVideoInformation.txt and NoViolenceVideoInformation.txt

# %% [markdown]
# ## Shuffle dataset

# %%
#function to shuffle (random) files
def shuffleFile(name_file):
    """
    Parameters:
        name_file: file to shuffle at random
        
    Output:
        Shuffled input file
    """
    import random
    lines = open(name_file).readlines()
    random.shuffle(lines)
    open(name_file, 'w').writelines(lines)

# %%
shuffleFile("MoviesFights.txt")
print('finished')
# Out:
# finished
