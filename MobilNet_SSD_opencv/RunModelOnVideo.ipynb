# %%
#Prediction on given video\

# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/GTA/videos/Violence/Fight-38.mp4"
# Out:
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# press key
# person detected
# press key
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# press key
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# person detected
# Traceback (most recent call last):
#   File "mobilenet_ssd_python.py", line 41, in <module>
# ...

# %%
#Prediction with own camera, no video given
# !python3 mobilenet_ssd_python.py

# %%
#write the commands to copy/paste in cell below
import glob
import os.path

mypath = '/Volumes/LogisP/Videos/Hockey_Fights/NoFights'
files = glob.glob(os.path.join(mypath, '*.avi'))
for file in files:
    print('print("Doe nu video:", "' + file + '")')
    print('!python3 mobilenet_ssd_python.py --video ' + '"' + file + '"')
# Out:
# print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no1_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no1_xvid.avi"
# print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no2_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no2_xvid.avi"
# print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no3_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no3_xvid.avi"
# print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no4_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no4_xvid.avi"
# print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no5_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no5_xvid.avi"
# ...

# %%
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no301_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no301_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no302_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no302_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no303_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no303_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no304_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no304_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no305_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no305_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no306_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no306_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no307_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no307_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no308_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no308_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no309_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no309_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no310_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no310_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no311_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no311_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no312_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no312_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no313_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no313_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no314_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no314_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no315_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no315_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no316_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no316_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no317_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no317_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no318_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no318_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no319_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no319_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no320_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no320_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no321_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no321_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no322_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no322_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no323_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no323_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no324_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no324_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no325_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no325_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no326_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no326_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no327_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no327_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no328_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no328_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no329_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no329_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no330_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no330_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no331_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no331_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no332_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no332_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no333_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no333_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no334_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no334_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no335_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no335_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no336_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no336_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no337_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no337_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no338_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no338_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no339_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no339_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no340_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no340_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no341_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no341_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no342_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no342_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no343_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no343_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no344_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no344_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no345_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no345_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no346_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no346_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no347_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no347_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no348_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no348_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no349_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no349_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no350_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no350_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no351_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no351_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no352_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no352_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no353_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no353_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no354_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no354_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no355_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no355_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no356_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no356_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no357_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no357_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no358_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no358_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no359_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no359_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no360_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no360_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no361_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no361_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no362_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no362_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no363_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no363_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no364_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no364_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no365_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no365_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no366_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no366_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no367_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no367_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no368_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no368_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no369_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no369_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no370_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no370_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no371_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no371_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no372_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no372_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no373_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no373_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no374_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no374_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no375_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no375_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no376_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no376_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no377_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no377_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no378_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no378_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no379_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no379_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no380_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no380_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no381_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no381_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no382_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no382_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no383_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no383_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no384_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no384_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no385_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no385_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no386_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no386_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no387_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no387_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no388_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no388_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no389_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no389_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no390_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no390_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no391_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no391_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no392_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no392_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no393_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no393_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no394_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no394_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no395_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no395_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no396_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no396_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no397_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no397_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no398_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no398_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no399_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no399_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no400_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no400_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no401_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no401_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no402_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no402_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no403_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no403_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no404_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no404_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no405_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no405_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no406_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no406_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no407_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no407_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no408_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no408_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no409_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no409_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no410_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no410_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no411_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no411_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no412_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no412_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no413_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no413_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no414_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no414_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no415_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no415_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no416_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no416_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no417_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no417_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no418_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no418_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no419_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no419_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no420_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no420_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no421_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no421_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no422_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no422_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no423_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no423_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no424_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no424_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no425_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no425_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no426_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no426_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no427_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no427_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no428_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no428_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no429_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no429_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no430_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no430_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no431_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no431_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no432_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no432_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no433_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no433_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no434_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no434_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no435_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no435_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no436_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no436_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no437_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no437_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no438_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no438_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no439_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no439_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no440_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no440_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no441_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no441_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no442_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no442_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no443_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no443_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no444_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no444_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no445_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no445_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no446_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no446_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no447_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no447_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no448_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no448_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no449_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no449_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no450_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no450_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no451_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no451_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no452_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no452_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no453_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no453_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no454_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no454_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no455_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no455_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no456_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no456_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no457_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no457_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no458_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no458_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no459_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no459_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no460_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no460_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no461_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no461_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no462_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no462_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no463_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no463_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no464_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no464_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no465_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no465_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no466_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no466_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no467_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no467_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no468_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no468_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no469_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no469_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no470_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no470_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no471_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no471_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no472_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no472_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no473_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no473_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no474_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no474_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no475_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no475_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no476_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no476_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no477_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no477_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no478_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no478_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no479_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no479_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no480_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no480_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no481_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no481_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no482_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no482_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no483_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no483_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no484_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no484_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no485_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no485_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no486_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no486_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no487_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no487_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no488_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no488_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no489_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no489_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no490_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no490_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no491_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no491_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no492_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no492_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no493_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no493_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no494_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no494_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no495_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no495_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no496_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no496_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no497_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no497_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no498_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no498_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no499_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no499_xvid.avi"
print("Doe nu video:", "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no500_xvid.avi")
# !python3 mobilenet_ssd_python.py --video "/Volumes/LogisP/Videos/Hockey_Fights/NoFights/no500_xvid.avi"
# Out:
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no301_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no302_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no303_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no304_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no305_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no306_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no307_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no308_xvid.avi
# person detected
# Doe nu video: /Volumes/LogisP/Videos/Hockey_Fights/NoFights/no309_xvid.avi
# Traceback (most recent call last):
#   File "mobilenet_ssd_python.py", line 41, in <module>
# ...
